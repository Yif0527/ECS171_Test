# %%
user_name='Yif0527'
access_token='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'

 git config --global user.email "you@example.com"
  git config --global user.name "Your Name"

# %%
#https://github.com/Yif0527/ECS171_Test.git


# %cd '/content/drive/MyDrive/ECS171'

# !git clone https://Yif0527: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@github.com/Yif0527/ECS171_Test.git
# Out:
# /content/drive/MyDrive/ECS171
# Cloning into 'ECS171_Test'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (3/3), done.

# %%
# !pwd
# %cd '/content/drive/MyDrive/ECS171/ECS171_Test'
# !git status
# Out:
# /content/drive/MyDrive/ECS171
# /content/drive/MyDrive/ECS171/ECS171_Test
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	git-version control.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git add -A
# !git status

# !git commit -m 'from Yif0527, add a notebook'
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	new file:   git-version control.ipynb
#
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@311a4888a83e.(none)')

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	new file:   git-version control.ipynb
